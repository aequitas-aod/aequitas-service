# %% [markdown]
# # Plan-and-Execute
#
# This notebook shows how to create a "plan-and-execute" style agent. This is heavily inspired by the [Plan-and-Solve](https://arxiv.org/abs/2305.04091) paper as well as the [Baby-AGI](https://github.com/yoheinakajima/babyagi) project.
#
# The core idea is to first come up with a multi-step plan, and then go through that plan one item at a time.
# After accomplishing a particular task, you can then revisit the plan and modify as appropriate.
#
#
# This compares to a typical [ReAct](https://arxiv.org/abs/2210.03629) style agent where you think one step at a time.
# The advantages of this "plan-and-execute" style agent are:
#
# 1. Explicit long term planning (which even really strong LLMs can struggle with)
# 2. Ability to use smaller/weaker models for the execution step, only using larger/better models for the planning step

# %% [markdown]
# ## Setup
#
# First, we need to install the packages required.

# %%
# %pip install -U mcp
# Out:
# Requirement already satisfied: mcp in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (1.27.2)
# Requirement already satisfied: anyio>=4.5 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.4.0)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.27.2)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (4.24.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (2.10.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (2.12.5)
# Requirement already satisfied: pyjwt[crypto]>=2.10.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.47.3)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from mcp) (0.35.0)
# Requirement already satisfied: idna>=2.8 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from anyio>=4.5->mcp) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from anyio>=4.5->mcp) (1.3.0)
# Requirement already satisfied: certifi in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.1->mcp) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.27.1->mcp) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp) (0.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp) (1.0.1)
# Requirement already satisfied: cryptography>=3.4.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp) (45.0.4)
# Requirement already satisfied: click>=7.0 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp) (8.1.8)
# Requirement already satisfied: cffi>=1.14 in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (1.16.0)
# Requirement already satisfied: pycparser in /home/albana/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.21)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#%%capture --no-stderr
# %pip install --quiet -U langgraph langchain langchain-community langchain-openai tavily-python langchain-core langchain-mcp-adapters
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next, we need to set API keys for OpenAI (the LLM we will use) and Tavily (the search tool we will use)

# %% [markdown]
# <div class="admonition tip">
#     <p class="admonition-title">Set up <a href="https://smith.langchain.com">LangSmith</a> for LangGraph development</p>
#     <p style="padding-top: 5px;">
#         Sign up for LangSmith to quickly spot issues and improve the performance of your LangGraph projects. LangSmith lets you use trace data to debug, test, and monitor your LLM apps built with LangGraph — read more about how to get started <a href="https://docs.smith.langchain.com">here</a>.
#     </p>
# </div>

# %% [markdown]
# ## Define Tools
#
# We will first define the tools we want to use. For this simple example, we will use a built-in search tool via Tavily. However, it is really easy to create your own tools - see documentation [here](https://python.langchain.com/docs/how_to/custom_tools) on how to do that.

# %%
import langchain
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_mcp_adapters.client import MultiServerMCPClient
langchain.debug = True


# MCP Client via HTTP
client = MultiServerMCPClient(
    {
        "mlops_tai_engineers": {
            "transport": "streamable_http",
            "url": "http://127.0.0.1:8082/mcp"  
        },
        "file_system": {
            "transport": "streamable_http",
            "url": "http://127.0.0.1:8080/mcp"  
        }
    }
)
structured_tools = await client.get_tools()
tools = structured_tools + [TavilySearchResults(max_results=3)]

# %% [markdown]
# ## Define our Execution Agent
#
# Now we will create the execution agent we want to use to execute tasks.
# Note that for this example, we will be using the same execution agent for each task, but this doesn't HAVE to be the case.

# %%
from langchain_openai import ChatOpenAI
from langchain.agents.factory import create_agent

#claude
#sonnet
#gpt 5
# Choose the LLM that will drive the agent
llm = ChatOpenAI(
    model="gpt-5.4",
    temperature=0.1,
    max_tokens=1000,
    timeout=30
)
prompt = "You are a helpful assistant."
agent_executor = create_agent(llm, tools, system_prompt=prompt)

# %%
#SYSTEM_PROMPT ="
USER_PROMPT = "Which is the list of operations for bias mitigation in data preparation stage using fairlearn library? Write only code implementation for each operation in separate python files located inside a folder on my Desktop."

# %%
res = await agent_executor.ainvoke({"messages": [("user", USER_PROMPT)]})
res
# Out:
# {'messages': [HumanMessage(content='Which is the list of operations for bias mitigation in data preparation stage using fairlearn library? Write only code implementation for each operation in separate python files located inside a folder on my Desktop.', additional_kwargs={}, response_metadata={}, id='9daebc47-3c47-445d-9b9b-da2d90077d71'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 1687, 'total_tokens': 1732, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24ZV8zQzdzVStc043uHS5G9j6U2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-c68f-7120-909a-a26fc3d138e3-0', tool_calls=[{'name': 'search_fairlearn_code', 'args': {'query': 'fairlearn bias mitigation data preparation stage operations pre-processing fairlearn reweighing preprocessing supported operations examples', 'k': 10}, 'id': 'call_FQNgdLIfwPrGVKHverXnWRr8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1687, 'output_tokens': 45, 'total_tokens': 1732, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\n.. _preprocessing:\n\nPreprocessing\n=============\n\n.. currentmodule:: fairlearn.preprocessing\n\nPreprocessing algorithms transform the dataset to mitigate possible unfairness\npresent in the data.\nPreprocessing algorithms in Fairlearn follow the :class:`sklearn.base.TransformerMixin`\nclass, meaning that they can :code:`fit` to the dataset and :code:`transform` it\n(or :code:`fit_transform` to fit and transform in one go).\n\n.. _correlation_remover:\n\nCorrelation Remover\n-------------------', 'id': 'lc_35122ba2-5a50-4a55-ba6e-8b5dc50429b9'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/faq.rst | type=.rst]\nCan the Fairlearn library be used to detect bias in datasets?\n    We do not have concrete plans for this at the present time.', 'id': 'lc_76cc8a0f-4cc7-4e64-a111-6deb6a948a3c'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/faq.rst | type=.rst]\nCan the Fairlearn library recommend ways to make my model fairer?\n    Right now we do not have an automated tool that would help you decide\n    which mitigation algorithm to use. Our focus is on expanding the\n    documentation and examples to highlight when each of the algorithms might\n    be more applicable.\n    Note that model training is just one step in the AI development and\n    deployment lifecycle, and other steps, such as data gathering and', 'id': 'lc_7cfad2fb-4f56-4d96-a2c2-8c44a3c26962'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/faq.rst | type=.rst]\nWhat unfairness mitigation techniques does Fairlearn support?\n    Please see our :ref:`mitigation` section.\n\nWhich ML libraries does Fairlearn support?\n    We have generally followed conventions of `scikit-learn`.\n    However, our mitigation algorithms can be used to augment\n    any ML algorithms that provide (or can be wrapped to provide) `fit()` and\n    `predict()` methods. Also, any classification or regression\n    algorithm can be evaluated using our metrics.', 'id': 'lc_37f890ce-3a12-45e3-92b1-68b36f705eda'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/about/index.rst | type=.rst]\nBelow we list the key areas that we prioritize in the short\nand medium term, but we are happy to consider other directions\nif they are aligned with the mission of Fairlearn and there is enough commitment\nfrom the contributors. If you want to get involved, please\n:ref:`reach out <communication>`. For concrete opportunities and\nwork in progress please review our\n`issues <https://github.com/fairlearn/fairlearn/issues>`_.', 'id': 'lc_0f231c8c-679a-484e-8d2b-3a530f31a0f3'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=test/unit/preprocessing/test_preprocessing_fairness.py | type=.py]\ndef test_preprocessing_mitigates_bias(\n    fairness_metric: Callable,\n    fairness_comparison_data: FairnessComparisonData,\n) -> None:\n    bootstrap_iterations = 20\n\n    fairness_metrics_values_with_mitigation = np.empty(bootstrap_iterations)\n    fairness_metrics_values_without_mitigation = np.empty(bootstrap_iterations)\n\n    for iteration in range(bootstrap_iterations):\n        sampled_data = fairness_comparison_data.bootstrap(seed=iteration)', 'id': 'lc_b96a3276-c02b-48c1-b3ff-1acffc88720c'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/about/index.rst | type=.rst]\nalgorithms.\nAdditionally, many use cases take the form of regression or ranking, rather\nthan classification.\nAs a result of these insights, fairness assessment and use-case notebooks\nbecame key components of Fairlearn.\nFairlearn also focuses on machine learning tasks beyond binary classification.', 'id': 'lc_f5acd9e0-78c3-413f-9218-4a56da41d777'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/about/index.rst | type=.rst]\nFairlearn was started in 2018 by Miro Dudik from Microsoft Research as a\nPython package to accompany the research paper,\nA Redu ...
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 2729, 'total_tokens': 2763, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24cvqZELlLmLGTfvWIJoUSITGFC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-cf3f-7e80-8647-dea815c313be-0', tool_calls=[{'name': 'search_fairlearn_code', 'args': {'query': 'CorrelationRemover class signature example fairlearn.preprocessing', 'k': 10}, 'id': 'call_NtFXhSgcnC7svVIbWue95Zgl', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2729, 'output_tokens': 34, 'total_tokens': 2763, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '[toolkit=fairlearn | file=docs/contributor_guide/contributing_documentation.rst | type=.rst]\n`code and docstrings <https://github.com/fairlearn/fairlearn/blob/main/fairlearn/preprocessing/_correlation_remover.py>`_\nof the :code:`CorrelationRemover` and the corresponding\n`generated page <file:///Users/tamara/FOSS/fairlearn/docs/_build/html/api_reference/generated/fairlearn.preprocessing.CorrelationRemover.html>`_.', 'id': 'lc_be8a1a89-c971-476c-a3dc-c1f34243d14a'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\n.. _preprocessing:\n\nPreprocessing\n=============\n\n.. currentmodule:: fairlearn.preprocessing\n\nPreprocessing algorithms transform the dataset to mitigate possible unfairness\npresent in the data.\nPreprocessing algorithms in Fairlearn follow the :class:`sklearn.base.TransformerMixin`\nclass, meaning that they can :code:`fit` to the dataset and :code:`transform` it\n(or :code:`fit_transform` to fit and transform in one go).\n\n.. _correlation_remover:\n\nCorrelation Remover\n-------------------', 'id': 'lc_66949280-3c2d-45c6-adb4-19996387d987'}, {'type': 'text', 'text': "[toolkit=fairlearn | file=examples/plot_correlationremover_before_after.py | type=.py]\n# %%\n# This notebook demonstrates the use of the :func:`fairlearn.preprocessing.CorrelationRemover`\n# class. We will show this by looking at the correlation matrices\n# of the dataset before and after the CorrelationRemover.\n#\n# Getting the Data\n# ================\n#\n# *This section may be skipped. It simply creates a dataset for\n# illustrative purposes*\n#\n# We will use the well-known UCI 'Adult' dataset as the basis of this\n# demonstration. This is not for a lending scenario, but we will regard", 'id': 'lc_ea228080-15c7-4aaa-8548-777b611d9bdc'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=fairlearn/preprocessing/__init__.py | type=.py]\n# Copyright (c) Microsoft Corporation and Fairlearn contributors.\n# Licensed under the MIT License.\n\n"""Preprocessing tools to help deal with sensitive attributes."""\n\nfrom ._correlation_remover import CorrelationRemover\nfrom ._prototype_representation_learner import PrototypeRepresentationLearner\n\n__all__ = ["CorrelationRemover", "PrototypeRepresentationLearner"]', 'id': 'lc_a63d2c66-d30b-4e24-8155-7719be67fa7d'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/api_reference/index.rst | type=.rst]\n:py:mod:`fairlearn.preprocessing`\n=================================\n\n.. automodule:: fairlearn.preprocessing\n    :no-members:\n    :no-inherited-members:\n\n.. autosummary::\n   :nosignatures:\n   :toctree: generated/\n   :template: class.rst\n\n   CorrelationRemover\n   PrototypeRepresentationLearner\n\n:py:mod:`fairlearn.reductions`\n==============================\n\n.. automodule:: fairlearn.reductions\n    :no-members:\n    :no-inherited-members:', 'id': 'lc_5d12002b-de2d-4c7a-9a0b-ace8caf78d0d'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=test/unit/preprocessing/test_preprocessing_fairness.py | type=.py]\nfrom fairlearn.datasets import fetch_adult\nfrom fairlearn.metrics import (\n    demographic_parity_difference,\n    equal_opportunity_difference,\n    equalized_odds_difference,\n)\nfrom fairlearn.preprocessing import CorrelationRemover, PrototypeRepresentationLearner\n\nPreprocessingAlgorithm = Union[CorrelationRemover, PrototypeRepresentationLearner]\n\n\n@dataclass(frozen=True)', 'id': 'lc_1f098cd2-c106-4ab6-b140-b560bcd19a42'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/installation_and_version_guide/v0.12.0.rst | type=.rst]\n:code:`scikit-learn` compatibility\n----------------------------------\n\n* Fairlearn is now compatible with :code:`scikit-learn` 1.6: :pr:`1451` by :user:`Tamara Atanasoska <tamaraatanasoska>`.\n* The :code:`fairlearn.preprocessing.CorrelationRemover` estimator is now fully :code:`scikit-learn` compatible: :pr:`1452` ...
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 3946, 'total_tokens': 3980, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2688}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24eWmeD5ow7S5x21NSId1HUfz2R', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-d6b2-73f0-871d-ad82c713c85e-0', tool_calls=[{'name': 'search_fairlearn_code', 'args': {'query': 'PrototypeRepresentationLearner signature example fairlearn.preprocessing', 'k': 10}, 'id': 'call_abuZDboFKlgwDyWZm41ZptQV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3946, 'output_tokens': 34, 'total_tokens': 3980, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\nPrototype Representation Learner\n--------------------------------\n\n:class:`~fairlearn.preprocessing.PrototypeRepresentationLearner` is a preprocessing algorithm and\na classifier that aims to learn a latent representation of the data that minimizes reconstruction\nerror, while simultaneously obfuscating information about sensitive features. It was introduced in\nZemel et al. (2013) :footcite:`pmlr-v28-zemel13`.', 'id': 'lc_7755f778-66e3-4200-aac9-e5d2ac9a1185'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=fairlearn/preprocessing/__init__.py | type=.py]\n# Copyright (c) Microsoft Corporation and Fairlearn contributors.\n# Licensed under the MIT License.\n\n"""Preprocessing tools to help deal with sensitive attributes."""\n\nfrom ._correlation_remover import CorrelationRemover\nfrom ._prototype_representation_learner import PrototypeRepresentationLearner\n\n__all__ = ["CorrelationRemover", "PrototypeRepresentationLearner"]', 'id': 'lc_e5cb31eb-3fb2-493d-beed-cef10ed436b1'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/api_reference/index.rst | type=.rst]\n:py:mod:`fairlearn.preprocessing`\n=================================\n\n.. automodule:: fairlearn.preprocessing\n    :no-members:\n    :no-inherited-members:\n\n.. autosummary::\n   :nosignatures:\n   :toctree: generated/\n   :template: class.rst\n\n   CorrelationRemover\n   PrototypeRepresentationLearner\n\n:py:mod:`fairlearn.reductions`\n==============================\n\n.. automodule:: fairlearn.reductions\n    :no-members:\n    :no-inherited-members:', 'id': 'lc_ea1ac52d-62d8-4155-87a5-261d23082e4e'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=fairlearn/preprocessing/_prototype_representation_learner.py | type=.py]\nExamples\n    --------\n    >>> import numpy as np\n    >>> from fairlearn.preprocessing import PrototypeRepresentationLearner\n    >>> X = np.array([[0, 1], [1, 0], [0, 0], [1, 1]])\n    >>> y = np.array([0, 1, 0, 1])\n    >>> sensitive_features = np.array([0, 0, 1, 1])\n    >>> prl = PrototypeRepresentationLearner(n_prototypes=2, random_state=42)\n    >>> prl.fit(X, y, sensitive_features=sensitive_features)\n    PrototypeRepresentationLearner(random_state=42)\n    >>> X_transformed = prl.transform(X)', 'id': 'lc_605c19d0-aea1-4c9f-9b7e-22fce33c51e2'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\n>>> prl = PrototypeRepresentationLearner(n_prototypes=4, max_iter=10)\n    >>> prl.fit(X_train, sensitive_features=sf_train)\n    PrototypeRepresentationLearner(max_iter=10, n_prototypes=4)\n    >>> X_train_transformed = prl.transform(X_train)\n    >>> X_test_transformed = prl.transform(X_test)\n\n\nReferences\n----------\n\n.. footbibliography::', 'id': 'lc_7980225b-db5f-4f32-9cf1-c1eb42195ca3'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/installation_and_version_guide/v0.13.0.rst | type=.rst]\nv0.13.0\n=======\n\nSummary\n-------\n\nThis release introduces a new method implementation, :code:`PrototypeRepresentationLearner`,\nwhich is based on the work of Zemel et al. (2013) :footcite:`pmlr-v28-zemel13`.\nYou can learn more about it :ref:`here <prototype_representation_learner>`.', 'id': 'lc_309cbfa9-bb63-4fb6-adb2-d32008c816e9'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=examples/plot_new_metrics.py | type=.py]\n# %%\n# The :class:`fairlearn.metrics.MetricFrame` object requires a\n# minimum of four arguments:\n#\n# 1. The underlying metric function(s) to be evaluated\n# 2. The true values\n# 3. The predicted values\n# 4. The sensitive feature values\n#\n# These are all passed as arguments to the constructor. If more than\n# one underlying metric is required (as in this case), then we must\n# provide them in a dictionary.\n#\n# The underlying metrics must have a signature ``fn(y_true, y_pred)``,', 'id': 'l ...
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 5156, 'total_tokens': 5171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3712}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24fZ4gnuhDIeB5kx14pgCP6uiQK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-dbc9-7333-9c1c-ca88da6e2c38-0', tool_calls=[{'name': 'list_user_directories', 'args': {}, 'id': 'call_SvRgIsEa3eIqq5yDJbRSP6ly', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5156, 'output_tokens': 15, 'total_tokens': 5171, 'input_token_details': {'audio': 0, 'cache_read': 3712}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '{\n  "directories": {\n    "Desktop": "/home/albana/Desktop",\n    "Documents": "/home/albana/Documents",\n    "Pictures": "/home/albana/Pictures",\n    "Videos": "/home/albana/Videos",\n    "Music": "/home/albana/Music",\n    "Downloads": "/home/albana/Downloads",\n    "Templates": "/home/albana/Templates",\n    "Public": "/home/albana/Public"\n  },\n  "error": null\n}', 'id': 'lc_2deb5c79-b3a8-49e1-8425-51b68539db3c'}], name='list_user_directories', id='ed81fbf6-a0c5-41b6-87f9-c5b9ea69a696', tool_call_id='call_SvRgIsEa3eIqq5yDJbRSP6ly', artifact={'structured_content': {'result': {'directories': {'Desktop': '/home/albana/Desktop', 'Documents': '/home/albana/Documents', 'Pictures': '/home/albana/Pictures', 'Videos': '/home/albana/Videos', 'Music': '/home/albana/Music', 'Downloads': '/home/albana/Downloads', 'Templates': '/home/albana/Templates', 'Public': '/home/albana/Public'}, 'error': None}}}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 5291, 'total_tokens': 5324, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 4736}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24gx8NUx1zdZifcG1F8xtmQEMRP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-df8a-7c70-a340-998781ec9bd7-0', tool_calls=[{'name': 'create_directory', 'args': {'directory_path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation'}, 'id': 'call_mlg1qgPV40QknfT3yFseQnVd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5291, 'output_tokens': 33, 'total_tokens': 5324, 'input_token_details': {'audio': 0, 'cache_read': 4736}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '{\n  "success": true,\n  "path": "/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation",\n  "error": null\n}', 'id': 'lc_372ba624-7c44-4883-ba78-26a37fd81309'}], name='create_directory', id='1c8db0cf-0fd5-4871-95ad-11ed6ae749c1', tool_call_id='call_mlg1qgPV40QknfT3yFseQnVd', artifact={'structured_content': {'result': {'success': True, 'path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation', 'error': None}}}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 5370, 'total_tokens': 5408, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5248}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24h4ndL9QkBLAfxoyEF9LH3FVC5', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-e562-7fd1-93f9-7fdf5c9ce0e9-0', tool_calls=[{'name': 'search_fairlearn_code', 'args': {'query': 'CorrelationRemover example fit_transform sensitive_feature_ids alpha fairlearn.preprocessing', 'k': 10}, 'id': 'call_PWJIfrbhyndStUTsVllVWniA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5370, 'output_tokens': 38, 'total_tokens': 5408, 'input_token_details': {'audio': 0, 'cache_read': 5248}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\n.. _preprocessing:\n\nPreprocessing\n=============\n\n.. currentmodule:: fairlearn.preprocessing\n\nPreprocessing algorithms transform the dataset to mitigate possible unfairness\npresent in the data.\nPreprocessing algorithms in Fairlearn follow the :class:`sklearn.base.TransformerMixin`\nclass, meaning that they can :code:`fit` to the dataset and :code:`transform` it\n(or :code:`fit_transform` to fit and transform in one go).\n\n.. _correlation_remover:\n\nCorrelation Remover\n-------------------', 'id': 'lc_a3fd360c-e4d8-4d10-b94a-74487634137d'}, {'type': 'text', 'text': "[toolkit=fairlearn | file=docs/user_guide/mitigation/preprocessing.rst | type=.rst]\n.. doctest:: mitigation_preprocessing\n\n    >>> cr = CorrelationRemover(sensitive_feature_ids=['race_AfricanAmerican'], alpha=0.5)\n    >>> cr.fit(X)\n    CorrelationRemover(alpha=0.5, sensitive_feature_ids=['race_AfricanAmerican'])\n    >>> X_transform = cr.transform(X)\n\nAs we can see in the visualization below, not all correlation between\n'race_AfricanAmerican' and the other columns was removed. This is exactly what\nwe would expect with :math:`\\alpha=0.5`.", 'id': 'lc_dbfad950-f5d8-422e-ae05-fa6d255415c5'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/contributor_guide/contributing_documentation.rst | type=.rst]\n`code and docstrings <https://github.com/fairlearn/fairlearn/blob/main/fairlearn/preprocessing/_correlation_remover.py>`_\nof the :code:`CorrelationRemover` and the corresponding\n`generated page <file:///Users/tamara/FOSS/fairlearn/docs/_build/html/api_reference/generated/fairlearn.preprocessing.CorrelationRemover.html>`_.', 'id': 'lc_dced24de-2bfe-492d-ac61-86938e43a3d6'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=fairlearn/preprocessing/__init__.py | type=.py]\n# Copyright (c) Microsoft Corporation and Fairlearn contributors.\n# Licensed under the MIT License.\n\n"""Preprocessing tools to help deal with sensitive attributes."""\n\nfrom ._correlation_remover import CorrelationRemover\nfrom ._prototype_representation_learner import PrototypeRepresentationLearner\n\n__all__ = ["CorrelationRemover", "PrototypeRepresentationLearner"]', 'id': 'lc_8bbea6c9-3fe4-4757-b158-7a38d7d02581'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/installation_and_version_guide/v0.12.0.rst | type=.rst]\n:code:`scikit-learn` compatibility\n----------------------------------\n\n* Fairlearn is now compatible with :code:`scikit-learn` 1.6: :pr:`1451` by :user:`Tamara Atanasoska <tamaraatanasoska>`.\n* The :code:`fairlearn.preprocessing.CorrelationRemover` estimator is now fully :code:`scikit-learn` compatible: :pr:`1452` by :user:`Tamara Atanasoska <tamaraatanasoska>`.', 'id': 'lc_b5f3b850-7bdd-4ba7-b2b2-ca48426e068c'}, {'type': 'text', 'text': "[toolkit=fairlearn | file=examples/plot_correlationremover_before_after.py | type=.py]\n# %%\n# This notebook demonstrates the use of the :func:`fairlearn.preprocessing.CorrelationRemover`\n# class. We will show this by looking at the correlation matrices\n# of the dataset before and after the CorrelationRemover.\n#\n# Getting the Data\n# ================\n#\n# *This section may be skipped. It simply creates a dataset for\n# illustrative purposes*\n#\n# We will use the well-known UCI 'Adult' dataset as the basis of this\n# demonstration. This is not for a lending scenario, but we will regard", 'id': 'lc_1e3a73ed-54f0-4189-9774-c712be08fc43'}, {'type': 'text', 'text': '[toolkit=fairlearn | file=docs/user_guide/installation_and_version_guide/v0.6.0.rst | type=.rst]\n* Add :class:`fairlearn.preprocessing.CorrelationRemover` preprocessing\n  technique. This removes correlations between sensitive and non-sensitive\n  features while retaining as much information as possible.\n* Add :code:`control_features` to the classification moments. These allow for\n  data stratific ...
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 245, 'prompt_tokens': 6643, 'total_tokens': 6888, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 5248}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24krpQK5ys5NFnDdGvLJdtlMM9K', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb90-eab4-7c81-818a-14a0d508b66c-0', tool_calls=[{'name': 'write_text_file_tool', 'args': {'file_path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/01_correlation_remover.py', 'content': 'import pandas as pd\nfrom fairlearn.preprocessing import CorrelationRemover\n\n# Example dataset\nX = pd.DataFrame(\n    {\n        "age": [25, 45, 31, 52, 23],\n        "income": [40000, 80000, 50000, 90000, 42000],\n        "education_years": [12, 16, 14, 18, 12],\n        "gender": [0, 1, 0, 1, 0],\n    }\n)\n\n# Remove correlation between sensitive feature(s) and the remaining features\nmitigator = CorrelationRemover(sensitive_feature_ids=["gender"], alpha=1.0)\nX_transformed = mitigator.fit_transform(X)\n\nprint("Original features:\\n", X)\nprint("\\nTransformed features:\\n", X_transformed)\n'}, 'id': 'call_owqkLxaqcZ9I4hA0TKLq0OJb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 6643, 'output_tokens': 245, 'total_tokens': 6888, 'input_token_details': {'audio': 0, 'cache_read': 5248}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '{\n  "success": true,\n  "path": "/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/01_correlation_remover.py",\n  "name": "01_correlation_remover.py",\n  "size": 583,\n  "mode": "write",\n  "error": null\n}', 'id': 'lc_cbd1bc7e-52fb-4c0e-b68b-6d47484cd1d7'}], name='write_text_file_tool', id='82e7d34a-6a3c-4d9e-8d87-a5ec6c364558', tool_call_id='call_owqkLxaqcZ9I4hA0TKLq0OJb', artifact={'structured_content': {'result': {'success': True, 'path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/01_correlation_remover.py', 'name': '01_correlation_remover.py', 'size': 583, 'mode': 'write', 'error': None}}}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 306, 'prompt_tokens': 6969, 'total_tokens': 7275, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 6272}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24orXyokIPbROzJWs45iRBJwa0F', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ecb91-013f-7503-883f-6e3d20261c7b-0', tool_calls=[{'name': 'write_text_file_tool', 'args': {'file_path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/02_prototype_representation_learner.py', 'content': 'import numpy as np\nfrom fairlearn.preprocessing import PrototypeRepresentationLearner\n\n# Example dataset\nX = np.array(\n    [\n        [25, 40000, 12],\n        [45, 80000, 16],\n        [31, 50000, 14],\n        [52, 90000, 18],\n        [23, 42000, 12],\n        [36, 62000, 15],\n    ]\n)\n\ny = np.array([0, 1, 0, 1, 0, 1])\nsensitive_features = np.array([0, 1, 0, 1, 0, 1])\n\n# Learn a fair latent/prototype-based representation\nmitigator = PrototypeRepresentationLearner(\n    n_prototypes=4,\n    max_iter=10,\n    random_state=42,\n)\nmitigator.fit(X, y, sensitive_features=sensitive_features)\nX_transformed = mitigator.transform(X)\n\nprint("Original features:\\n", X)\nprint("\\nTransformed features:\\n", X_transformed)\n'}, 'id': 'call_swN2FIhzAKUEf55T0qRoj4Hf', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 6969, 'output_tokens': 306, 'total_tokens': 7275, 'input_token_details': {'audio': 0, 'cache_read': 6272}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'type': 'text', 'text': '{\n  "success": true,\n  "path": "/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/02_prototype_representation_learner.py",\n  "name": "02_prototype_representation_learner.py",\n  "size": 707,\n  "mode": "write",\n  "error": null\n}', 'id': 'lc_a7c04c23-e251-45a9-a128-21048315300b'}], name='write_text_file_tool', id='2dd8ee66-7d63-44c6-8146-ffb64f9c1ef8', tool_call_id='call_swN2FIhzAKUEf55T0qRoj4Hf', artifact={'structured_content': {'result': {'success': True, 'path': '/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation/02_prototype_representation_learner.py', 'name': '02_prototype_representation_learner.py', 'size': 707, 'mode': 'write', 'error': None}}}),
#   AIMessage(content='Implemented Fairlearn data-preparation bias mitigation operations in separate Python files here:\n\n`/home/albana/Desktop/fairlearn_data_preparation_bias_mitigation`\n\nFiles created:\n- `01_correlation_remover.py`\n- `02_prototype_representation_learner.py`', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 7362, 'total_tokens': 7422, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 6784}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-2026-03-05', 'system_fingerprint': None, 'id': 'chatcmpl-Dr24rxgwA1Mk6q2OWqihHLOau7Idf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ecb91-0b6a-79b1-a373-ca84f4bf551d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7362, 'output_tokens': 60, 'total_tokens': 7422, 'input_token_details': {'audio': 0, 'cache_read': 6784}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ### Dynamic Model
#
# Dynamic models are selected at runtime based on the current state and context. This enables sophisticated routing logic and cost optimization.

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse


basic_model = ChatOpenAI(model="gpt-4.1-mini")
advanced_model = ChatOpenAI(model="gpt-4.1")

@wrap_model_call
def dynamic_model_selection(request: ModelRequest, handler) -> ModelResponse:
    """Choose model based on conversation complexity."""
    message_count = len(request.state["messages"])

    if message_count > 10:
        # Use an advanced model for longer conversations
        model = advanced_model
    else:
        model = basic_model

    return handler(request.override(model=model))

agent = create_agent(
    model=basic_model,  # Default model
    tools=tools,
    middleware=[dynamic_model_selection]
)

# %% [markdown]
# ## Define the State
#
# Let's now start by defining the state the track for this agent.
#
# First, we will need to track the current plan. Let's represent that as a list of strings.
#
# Next, we should track previously executed steps. Let's represent that as a list of tuples (these tuples will contain the step and then the result)
#
# Finally, we need to have some state to represent the final response as well as the original input.

# %%
import operator
from typing import Annotated, List, Tuple
from typing_extensions import TypedDict


class PlanExecute(TypedDict):
    input: str
    plan: List[str]
    past_steps: Annotated[List[Tuple], operator.add]
    response: str

# %% [markdown]
# ## Planning Step
#
# Let's now think about creating the planning step. This will use function calling to create a plan.

# %% [markdown]
# <div class="admonition note">
#     <p class="admonition-title">Using Pydantic with LangChain</p>
#     <p>
#         This notebook uses Pydantic v2 <code>BaseModel</code>, which requires <code>langchain-core >= 0.3</code>. Using <code>langchain-core < 0.3</code> will result in errors due to mixing of Pydantic v1 and v2 <code>BaseModels</code>.
#     </p>
# </div>

# %%
from pydantic import BaseModel, Field


class Plan(BaseModel):
    """Plan to follow in future"""

    steps: List[str] = Field(
        description="different steps to follow, should be in sorted order"
    )

# %%
from langchain_core.prompts import ChatPromptTemplate

planner_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.""",
        ),
        ("placeholder", "{messages}"),
    ]
)
planner = planner_prompt | ChatOpenAI(
    model="gpt-5.4", temperature=0
).with_structured_output(Plan)

# %%
planner.invoke(
    {
        "messages": [
            #("user", "Which are the operations for data preparation stage in the lifecycle of an AI product?")
            ("user", "Which are the operations for data preparation stage in the lifecycle of an AI product?")
        ]
    }
)
# Out:
# Plan(steps=['Identify the standard data preparation operations commonly performed in an AI product lifecycle after data collection and before model training.', 'List the core operations: data cleaning, data integration, data transformation, data labeling/annotation, data reduction, and data splitting.', 'State these operations clearly as the answer to the question.'])

# %% [markdown]
# ## Re-Plan Step
#
# Now, let's create a step that re-does the plan based on the result of the previous step.

# %%
from typing import Union


class Response(BaseModel):
    """Response to user."""

    response: str


class Act(BaseModel):
    """Action to perform."""

    action: Union[Response, Plan] = Field(
        description="Action to perform. If you want to respond to user, use Response. "
        "If you need to further use tools to get the answer, use Plan."
    )


replanner_prompt = ChatPromptTemplate.from_template(
    """For the given objective, come up with a simple step by step plan. \
This plan should involve individual tasks, that if executed correctly will yield the correct answer. Do not add any superfluous steps. \
The result of the final step should be the final answer. Make sure that each step has all the information needed - do not skip steps.

Your objective was this:
{input}

Your original plan was this:
{plan}

You have currently done the follow steps:
{past_steps}

Update your plan accordingly. If no more steps are needed and you can return to the user, then respond with that. Otherwise, fill out the plan. Only add steps to the plan that still NEED to be done. Do not return previously done steps as part of the plan."""
)


replanner = replanner_prompt | ChatOpenAI(
    model="gpt-5.4", temperature=0
).with_structured_output(Act)

# %% [markdown]
# ## Create the Graph
#
# We can now create the graph!

# %%
from typing import Literal
from langgraph.graph import END
from langgraph.prebuilt import ToolNode


async def execute_step(state: PlanExecute):
    plan = state["plan"]
    plan_str = "\n".join(f"{i + 1}. {step}" for i, step in enumerate(plan))
    task = plan[0]
    task_formatted = f"""For the following plan:
{plan_str}\n\nYou are tasked with executing step {1}, {task}."""
    agent_response = await agent_executor.ainvoke(
        {"messages": [("user", task_formatted)]}
    )
    return {
        "past_steps": [(task, agent_response["messages"][-1].content)],
    }


async def plan_step(state: PlanExecute):
    plan = await planner.ainvoke({"messages": [("user", state["input"])]})
    return {"plan": plan.steps}


async def replan_step(state: PlanExecute):
    output = await replanner.ainvoke(state)
    if isinstance(output.action, Response):
        return {"response": output.action.response}
    else:
        return {"plan": output.action.steps}


def should_end(state: PlanExecute):
    if "response" in state and state["response"]:
        return END
    else:
        return "agent"

# %%
from langgraph.graph import StateGraph, START

workflow = StateGraph(PlanExecute)

# Add the plan node
workflow.add_node("planner", plan_step)

# Add the execution step
workflow.add_node("agent", execute_step)

# Add a replan node
workflow.add_node("replan", replan_step)


workflow.add_edge(START, "planner")

# From plan we go to agent
workflow.add_edge("planner", "agent")

# From agent, we replan
workflow.add_edge("agent", "replan")


workflow.add_conditional_edges(
    "replan",
    # Next, we pass in the function that will determine which node is called next.
    should_end,
    ["agent", END],
)

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile()

# %%
from IPython.display import Image, display

display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# %%
config = {"recursion_limit": 50}
inputs = {"input": USER_PROMPT}
async for event in app.astream(inputs, config=config):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# {'plan': ['List the standard data preparation operations in an AI product lifecycle: data collection, data cleaning, data labeling/annotation, data transformation/preprocessing, data augmentation, data splitting, and data validation/quality checks.', 'Create one separate text file on the Desktop for each operation, naming each file after the operation.', 'Write the name of the operation and a short description of it into its corresponding file.', 'The final answer is the completed set of separate Desktop files, one for each data preparation operation.']}
# {'past_steps': [('List the standard data preparation operations in an AI product lifecycle: data collection, data cleaning, data labeling/annotation, data transformation/preprocessing, data augmentation, data splitting, and data validation/quality checks.', 'Standard data preparation operations in an AI product lifecycle:\n\n1. Data collection\n2. Data cleaning\n3. Data labeling/annotation\n4. Data transformation/preprocessing\n5. Data augmentation\n6. Data splitting\n7. Data validation/quality checks')]}
# {'plan': ['Create these separate files on the Desktop: Data Collection.txt, Data Cleaning.txt, Data Labeling Annotation.txt, Data Transformation Preprocessing.txt, Data Augmentation.txt, Data Splitting.txt, and Data Validation Quality Checks.txt.', 'Write the corresponding operation name and a short description into each file: Data collection — gathering raw data from relevant sources; Data cleaning — fixing missing, incorrect, duplicate, or inconsistent data; Data labeling/annotation — assigning tags or ground-truth labels to data; Data transformation/preprocessing — converting data into a usable format for models; Data augmentation — creating additional training examples from existing data; Data splitting — dividing data into training, validation, and test sets; Data validation/quality checks — verifying data accuracy, completeness, consistency, and suitability.', 'The final answer is the completed set of separate files on the Desktop, one for each data preparation operation.']}
# {'past_steps': [('Create these separate files on the Desktop: Data Collection.txt, Data Cleaning.txt, Data Labeling Annotation.txt, Data Transformation Preprocessing.txt, Data Augmentation.txt, Data Splitting.txt, and Data Validation Quality Checks.txt.', 'Step 1 completed: the 7 empty `.txt` files were created on the Desktop.\n\nCreated files:\n- Data Collection.txt\n- Data Cleaning.txt\n- Data Labeling Annotation.txt\n- Data Transformation Preprocessing.txt\n- Data Augmentation.txt\n- Data Splitting.txt\n- Data Validation Quality Checks.txt')]}
# {'plan': ['Write the corresponding operation name and short description into each existing Desktop file: Data Collection.txt — "Data collection: gathering raw data from relevant sources."; Data Cleaning.txt — "Data cleaning: fixing missing, incorrect, duplicate, or inconsistent data."; Data Labeling Annotation.txt — "Data labeling/annotation: assigning tags or ground-truth labels to data."; Data Transformation Preprocessing.txt — "Data transformation/preprocessing: converting data into a usable format for models."; Data Augmentation.txt — "Data augmentation: creating additional training examples from existing data."; Data Splitting.txt — "Data splitting: dividing data into training, validation, and test sets."; Data Validation Quality Checks.txt — "Data validation/quality checks: verifying data accuracy, completeness, consistency, and suitability."', 'The final answer is the completed set of separate files on the Desktop, one for each data preparation operation.']}
# {'past_steps': [('Write the corresponding operation name and short description into each existing Desktop file: Data Collection.txt — "Data collection: gathering raw data from relevant sources."; Data Cleaning.txt — "Data cleaning: fixing missing, incorrect, duplicate, or inconsistent data."; Data Labeling Annotation.txt — "Data labeling/annotation: assigning tags or ground-truth labels to data."; Data Transformation Preprocessing.txt — "Data transformation/preprocessing: converting data into a usable format for models."; Data Augmentation.txt — "Data augmentation: creating additional training examples from existing data."; Data Splitting.txt — "Data splitting: dividing data into training, validation, and test sets."; Data Validation Quality Checks.txt — "Data validation/quality checks: verifying data accuracy, completeness, consistency, and suitability."', 'Done. I wrote the specified operation name and description into all 7 Desktop files.')]}
# {'response': 'All required steps are complete. The separate Desktop files have been created and filled with the data preparation operations:\n\n- Data Collection.txt\n- Data Cleaning.txt\n- Data Labeling Annotation.txt\n- Data Transformation Preprocessing.txt\n- Data Augmentation.txt\n- Data Splitting.txt\n- Data Validation Quality Checks.txt\n\nThe final answer is the completed set of separate files on the Desktop, one for each data preparation operation.'}

# %% [markdown]
# ## Conclusion
#
# One known limitations of the above design is that each task is still executed in sequence, meaning embarrassingly parallel operations all add to the total execution time. We could improve on this by having each task represented as a DAG (similar to LLMCompiler), rather than a regular list.

# %% [markdown]
# # References
#
# - https://github.com/ashishpatel26/500-AI-Agents-Projects?tab=readme-ov-file#framework-name-crewai
# - https://github.com/langchain-ai/langgraph/blob/23961cff61a42b52525f3b20b4094d8d2fba1744/docs/docs/tutorials/plan-and-execute/plan-and-execute.ipynb
# - https://github.com/langchain-ai/langgraph/blob/23961cff61a42b52525f3b20b4094d8d2fba1744/docs/docs/tutorials/code_assistant/langgraph_code_assistant.ipynb
